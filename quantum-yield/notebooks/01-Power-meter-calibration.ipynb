# %% [markdown]
# # Power-meter calibration
# **Last update**: 18/12/2020 \
# **Author**: Jean Matias

# %%
# %matplotlib notebook
import sys
sys.path.append('../scripts/')
from calibration import *

# %% [markdown]
# ## Calibration data

# %%
PMCalibrationFile = '../data/equipment-calibration/calibration_data.csv'
metadataFile = '../data/equipment-calibration/calibration_data_metadata.csv'
# loads metadata
metadata = pd.read_csv(metadataFile)
 # loads calibration data 
calibrationData = pd.read_csv(PMCalibrationFile)

# %%
metadata
# Out:
#              column units             plot_label  \
# 0        daq_output     V             Signal (V)
# 1    driver_current    mA    Driver current (mA)
# 2         daq_input     V             Signal (V)
# 3        pm_reading    mW             Power (mW)
# 4             laser    nm  Laser wavelength (nm)
# 5          pm_range    mW             Power (mW)
# 6     desity_filter    OD      Dens. Filter (OD)
# 7  acquisition_date   NaN                   Date
#
#                                          description
# 0  Analog output to the laser driver. It modulate...
# 1                     Current applied to diode laser
# 2  Power meter analog output connected to daq inp...
# 3  Power meter readings from power meter digital ...
# 4                             Laser diode wavelength
# 5  Power meter detection range. Different ranges ...
# 6           Filter placed in front of the laser beam
# 7                         Date in format: DD/MM/YYYY

# %%
calibrationData
# Out:
#      daq_output  driver_current  daq_input  pm_reading  laser  pm_range  \
# 0           0.0             0.0   0.000000        0.00    976     600.0
# 1           2.5           369.6   0.472600      146.10    976     600.0
# 2           5.0           739.4   1.048000      320.80    976     600.0
# 3           5.4           798.5   1.135700      347.50    976     600.0
# 4           0.0             0.0   0.000735        0.00    785      91.0
# ..          ...             ...        ...         ...    ...       ...
# 116         0.7           103.9   0.712500        3.28    785       9.1
# 117         0.8           118.8   0.997000        4.60    785       9.1
# 118         0.9           133.6   1.282000        5.91    785       9.1
# 119         1.0           148.5   1.563000        7.21    785       9.1
# 120         1.1           163.4   1.862000        8.59    785       9.1
#
#      density_filter acquisition_date
# 0                 0       04/12/2020
# ...

# %% [markdown]
# ## Laser 976nm

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=600, densityFilter=0, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[305.16892805223625, -0.37612596104816115], R^2=0.9999232722423607

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=60, densityFilter=0, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[30.39698158328316, -0.010481698576021081], R^2=0.9999996900268153

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=60, densityFilter=1, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[30.409357578561274, -0.01900625466950857], R^2=0.9999994128104059

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=60, densityFilter=2, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[30.39994259956009, -0.01956752784108068], R^2=0.9999965820693646

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=6, densityFilter=1, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[3.060854876112552, -0.002647276747303086], R^2=0.9999988364928478

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=6, densityFilter=2, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[3.056861195203281, 0.0004596178086155331], R^2=0.9999916485123388

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=6, densityFilter=3, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[3.05646499489003, -0.0014412587468244475], R^2=0.9999991048458292

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=0.6, densityFilter=3, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[0.3044419787140517, -0.0002939005227472617], R^2=0.9999981581030905

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=0.6, densityFilter=4, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[0.3044496254543514, -0.00015905524110831104], R^2=0.9999950245891708

# %%
coeffs, r_val = calibratePM(laser=976, pmRange=0.06, densityFilter=4, degree=1)
print(f'{coeffs=}, R^2={r_val**2}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# coeffs=[0.030445852587082198, 4.4029242213900366e-05], R^2=0.9998604633759899
